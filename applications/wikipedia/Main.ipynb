# %% [markdown]
# # Тематическая модель Википедии
#
# ## Задачи
#
# - Подготовить многомодальный Bag-of-words по выгрузкам на нескольких языках
#   - [Gensim: prepare wikipedia](https://radimrehurek.com/gensim/wiki.html)
# - Обучить тематическую модель с использованием CLI, использовать параллельность
# - Показать ускорение обучения за счет параллельности
