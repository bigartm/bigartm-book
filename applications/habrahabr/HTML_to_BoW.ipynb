# %%
import nltk

# %%
from nltk import word_tokenize

# %%
import json
with open('/home/romovpa/habrahabr-dataset/dataset_10k/habr_posts/246153') as f:
    post = json.load(f)

# %%
post['content_html']
# Out:
# u'<div class="content html_format">\n    \t<h2>\u0412\u0432\u0435\u0434\u0435\u043d\u0438\u0435</h2><br><iframe src="//player.vimeo.com/video/2564771" width="500" height="281" frameborder="0" webkitallowfullscreen mozallowfullscreen allowfullscreen></iframe><br>\r\n\u041a\u043e\u0433\u0434\u0430 \u0433\u043e\u0432\u043e\u0440\u044f\u0442 \u043e \u043f\u0435\u0440\u0435\u0434\u0430\u0447\u0438 \u0432\u0438\u0434\u0435\u043e \u043f\u043e \u0441\u0435\u0442\u0438, \u0432 \u043e\u0441\u043d\u043e\u0432\u043d\u043e\u043c \u0440\u0435\u0447\u044c \u0438\u0434\u0451\u0442 \u043e \u0432\u0438\u0434\u0435\u043e-\u043a\u043e\u0434\u0435\u043a\u0430\u0445 \u0438 \u0440\u0430\u0437\u0440\u0435\u0448\u0435\u043d\u0438\u0438. \u0421\u043e\u0431\u0441\u0442\u0432\u0435\u043d\u043d\u043e \u043e \u043f\u0435\u0440\u0435\u0434\u0430\u0447\u0435 \u0432\u0438\u0434\u0435\u043e \u0441\u043b\u044b\u0448\u043d\u043e \u043d\u0435 \u0442\u0430\u043a \u0438 \u043c\u043d\u043e\u0433\u043e. \u0417\u0434\u0435\u
# ...

# %%
html = post['content_html']

from BeautifulSoup import BeautifulSoup
raw = BeautifulSoup(html).getText()
tokens = word_tokenize(raw)

# %%
for i in tokens:
    print i
# Out:
# ВведениеКогда
# говорят
# о
# передачи
# видео
# по
# сети
# ,
# в
# основном
# речь
# идёт
# о
# видео-кодеках
# и
# разрешении
# .
# Собственно
# о
# передаче
# видео
# слышно
# не
# так
# и
# много
# .
# Здесь
# я
# бы
# хотел
# пролить
# немного
# света
# на
# проблему
# борьбы
# с
# потерями
# в
# сети
# при
# передачи
# видео
# в
# режиме
# видеоконференций
# .
# Почему
# потери
# —
# это
# так
# важно
# ?
# Да
# потому
# что
# нельзя
# просто
# так
# взять
# и
# пропустить
# хоть
# один
# видео
# пакет
# (
# в
# отличии
# от
# аудио
# )
# ,
# т.к
# .
# любой
# приличный
# видео-кодек
# основан
# на
# том
# ,
# что
# последовательные
# кадры
# отличаются
# не
# сильно
# и
# достаточно
# закодировать
# и
# передать
# только
# разницу
# между
# кадрами
# .
# Получается
# ,
# что
# (
# почти
# )
# любой
# кадр
# зависит
# от
# предыдущих
# .
# И
# картинка
# при
# потерях
# разваливается
# (
# хотя
# некоторым
# это
# даже
# нравится
# )
# .
# Почему
# видеоконференции
# ?
# ...

# %%
b = BeautifulSoup(html)

# %%
b.getText()
# Out:
# u'\u0412\u0432\u0435\u0434\u0435\u043d\u0438\u0435\u041a\u043e\u0433\u0434\u0430 \u0433\u043e\u0432\u043e\u0440\u044f\u0442 \u043e \u043f\u0435\u0440\u0435\u0434\u0430\u0447\u0438 \u0432\u0438\u0434\u0435\u043e \u043f\u043e \u0441\u0435\u0442\u0438, \u0432 \u043e\u0441\u043d\u043e\u0432\u043d\u043e\u043c \u0440\u0435\u0447\u044c \u0438\u0434\u0451\u0442 \u043e \u0432\u0438\u0434\u0435\u043e-\u043a\u043e\u0434\u0435\u043a\u0430\u0445 \u0438 \u0440\u0430\u0437\u0440\u0435\u0448\u0435\u043d\u0438\u0438. \u0421\u043e\u0431\u0441\u0442\u0432\u0435\u043d\u043d\u043e \u043e \u043f\u0435\u0440\u0435\u0434\u0430\u0447\u0435 \u0432\u0438\u0434\u0435\u043e \u0441\u043b\u044b\u0448\u043d\u043e \u043d\u0435 \u0442\u0430\u043a \u0438 \u043c\u043d\u043e\u0433\u043e. \u0417\u0434\u0435\u0441\u044c \u044f \u0431\u044b \u0445\u043e\u0442\u0435\u043b \u043f\u0440\u043e\u043b\u0438\u0442\u044c \u043d\u0435\u043c\u043d\u043e\u0433\u043e \u0441\u0432\u0435\u0442\u0430 \u043d\u0430 \u043f\u0440\u043e\u0431
# ...

# %%
# !ls /home/romovpa/habrahabr-dataset/dataset_10k/habr_posts/246153
# Out:
# 101121	227197	230003	232743	235447	238107	240773	243479	246131	248901
# 102072	227199	230007	232745	235449	238109	240775	243481	246133	248903
# 104066	227201	230009	232747	235451	238113	240779	243483	246135	248907
# 108929	227203	230011	232749	235453	238115	240781	243485	246137	248909
# 110751	227205	230015	232751	235455	238117	240783	243487	246139	248911
# 111542	227209	230019	232753	235457	238119	240785	243489	246143	248913
# 115180	227211	230021	232755	235459	238121	240787	243493	246153	248917
# 118375	227213	230023	232757	235461	238123	240789	243495	246155	248919
# 126869	227215	230027	232759	235463	238125	240791	243497	246159	248921
# 130994	227219	230031	232761	235465	238127	240793	243499	246161	248933
# 139455	227221	230033	232767	235467	238129	240795	243501	246169	248935
# 141198	227223	230035	232771	235471	238131	240799	243503	246171	248937
# 149008	227225	230037	232775	235473	238133	240803	243505	246173	248939
# ...
